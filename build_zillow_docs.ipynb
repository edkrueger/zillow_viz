# %% [markdown]
# # Building Searchable Documentation for Zillow's API Codes on Quandl's API Client
# ## *Edward Krueger*

# %% [markdown]
# The Quandl documentation for the Zillow data at https://www.quandl.com/data/ZILLOW-Zillow-Real-Estate-Research/documentation/data-organization, isn't quite correct or complete. Even if it were, a searchable dictionary would be useful. Also, Quandl's search isn't completely useful. Fortunately, there is a zipped file with all of the codes and their descriptions.
#
# I will build my own data dictionary and search for the data.

# %% [markdown]
# ## Setup

# %% [markdown]
# ### Import and configure packages

# %%
# import packages to unzip the list of Quandl Codes
from io import BytesIO
from zipfile import ZipFile
import urllib.request

# import and configure pandas
import pandas as pd
pd.options.display.max_colwidth = 100
pd.set_option('display.max_rows', 1000)

# import quandl and configure API key
import quandl
quandl.ApiConfig.api_key = "qTtZzvXVi7jgbHx5tng8"

# %% [markdown]
# ### Build functions to create and search the documentation

# %%
# strips characters that are not in the alphabet from a string
def strip_non_alpha(s):
    return "".join(filter(lambda x : x.isalpha(), s))

# converts an area type code into its area type
def area_type_code_to_area_type(s):
    if s =="S":
        return "State"
    elif s == "CO":
        return "County"
    elif s == "M":
        return "Greater Metropolitan Area"
    elif s == "C":
        return "City"
    elif s == "N":
        return "Neighborhood"
    elif s == "Z":
        return "Zip Code"
    else:
        return ""

# loads and formats the documentation from the zip file
def load_documentation(url_str = "https://www.quandl.com/api/v3/databases/ZILLOW/codes?api_key=qTtZzvXVi7jgbHx5tng8"):
    
    # open the zip file as a ZipFile
    url = urllib.request.urlopen(url_str)
    zip_file = ZipFile(BytesIO(url.read()))
    
    # find the name of the only file and open it
    names = zip_file.namelist()
    name = names[0]
    
    # load into pandas
    df = pd.read_csv(zip_file.open(name), header = None, low_memory = False)
    
    # rename to columns
    df.columns = ["code", "description"]
    
    # get the area type and area code info
    df["zillow_code"] = df["code"].apply(lambda x : x.split("/")[1])
    df["area_cat_code"] = df["zillow_code"].apply(lambda x : x.split("_")[0])
    df["area_type_code"] = df["area_cat_code"].apply(lambda x : strip_non_alpha(x[0:2]))
    df["area_type"] = df["area_type_code"].apply(area_type_code_to_area_type)
    
    # drop duplicate area_cat_codes
    df = df.drop_duplicates("area_cat_code")
    
    # strip the first part of the description
    df["description"] = df["description"].apply(lambda x : x.split(":")[1])
    df["area"] = df["description"].apply(lambda x : x.split("-")[-1].strip())
    
    # drop unessesary variables
    df = df[["area", "area_cat_code", "area_type_code", "area_type"]]
    
    df["area_type_code"] = pd.Categorical(df["area_type_code"], ["S", "CO", "M", "C", "N", "Z"])
    df.sort_values("area_type_code")
    return df

def filter_documentation(df, area_type_code):
    # subset by area_cat
    df = df[df["area_type_code"] == area_type_code]
    df = df.set_index("area").sort_index()
    return df
    
def search_documentation(df, term):
    df = df[df["area"].str.lower().str.contains(term.lower())]
    df = df[["area", "area_type", "area_cat_code"]]
    return df

# %% [markdown]
# ## Explore the Documentation

# %% [markdown]
# ### Load the documentation

# %%
df = load_documentation()

# %% [markdown]
# ### Display the shape, head and tail of the documentation

# %%
df.shape
# Out:
# (74410, 4)

# %%
df.head()
# Out:
#             area area_cat_code area_type_code area_type
# 0       Arkansas            S4              S     State
# 1       Colorado            S7              S     State
# 2         Alaska            S2              S     State
# 3        Alabama            S3              S     State
# 4  United States            S1              S     State

# %%
df.tail()
# Out:
#                        area area_cat_code area_type_code area_type
# 1423949       Woodville, MS        C24926              C      City
# 1427109     Middlesboro, KY        C24924              C      City
# 1427136  Pomfret Center, CT        C24925              C      City
# 1427999        Clarkton, MO        C24928              C      City
# 1428160    New Rockford, ND        C24929              C      City

# %% [markdown]
# ### Create a DataFrame for each type of area

# %%
# find and show the unique area categories and thier codes
df[["area_type_code", "area_type"]].drop_duplicates().reset_index(drop = True)
# Out:
#   area_type_code                  area_type
# 0              S                      State
# 1              M  Greater Metropolitan Area
# 2             CO                     County
# 3              N               Neighborhood
# 4              C                       City
# 5              Z                   Zip Code

# %%
# create a DataFrame for each type
S_df = filter_documentation(df, "S")
M_df = filter_documentation(df, "M")
C_df = filter_documentation(df, "C")
CO_df = filter_documentation(df, "CO")
N_df = filter_documentation(df, "N")
Z_df = filter_documentation(df, "Z")

# %% [markdown]
# ## Search the documentation for Austin

# %%
result_df = search_documentation(df, "austin")
result_df
# Out:
#                                         area                  area_type  \
# 4018                              Austin, TX  Greater Metropolitan Area
# 13351                             Austin, MN  Greater Metropolitan Area
# 42197                             Austin, TX                     County
# 121430             South Austin, Chicago, IL               Neighborhood
# 121685             North Austin, Chicago, IL               Neighborhood
# 123005              Barton Creek, Austin, TX               Neighborhood
# 126939             West Oak Hill, Austin, TX               Neighborhood
# 127010             East Oak Hill, Austin, TX               Neighborhood
# 135535               Austin Avenue, Waco, TX               Neighborhood
# 137280            Austin's Colony, Bryan, TX               Neighborhood
# 138448               South Lamar, Austin, TX               Neighborhood
# 138554                  Downtown, Austin, TX               Neighborhood
# 142501              Windsor Park, Austin, TX               Neighborhood
# 142561           West University, Austin, TX               Neighborhood
# 142762             Garrison Park, Austin, TX               Neighborhood
# 142808                Montopolis, Austin, TX               Neighborhood
# 142963                   MLK 183, Austin, TX               Neighborhood
# 142973                 Brentwood, Austin, TX               Neighborhood
# 143076          South River City, Austin, TX               Neighborhood
# 143186                   Bouldin, Austin, TX               Neighborhood
# 143227                North Loop, Austin, TX               Neighborhood
# 143231           Old West Austin, Austin, TX               Neighborhood
# 143233                    Zilker, Austin, TX               Neighborhood
# 143239                   Govalle, Austin, TX               Neighborhood
# 143246                  Rosewood, Austin, TX               Neighborhood
# 143260                 Crestview, Austin, TX               Neighborhood
# 143307       Central East Austin, Austin, TX               Neighborhood
# 143331                       MLK, Austin, TX               Neighborhood
# 143390                   Galindo, Austin, TX               Neighborhood
# 143475                    Dawson, Austin, TX               Neighborhood
# 145450                  Rosedale, Austin, TX               Neighborhood
# 153158                 Riverside, Austin, TX               Neighborhood
# 153196             North Burnett, Austin, TX               Neighborhood
# 154126               Parker Lane, Austin, TX               Neighborhood
# 154441           Pleasant Valley, Austin, TX               Neighborhood
# 154523              Barton Hills, Austin, TX               Neighborhood
# 154583          North University, Austin, TX               Neighborhood
# 155726              North Austin, Austin, TX               Neighborhood
# 155832              Wells Branch, Austin, TX               Neighborhood
# 155834            Georgian Acres, Austin, TX               Neighborhood
# 156921                 Hyde Park, Austin, TX               Neighborhood
# 159119             Windsor Hills, Austin, TX               Neighborhood
# 160104                  Mckinney, Austin, TX               Neighborhood
# 162437         North Shoal Creek, Austin, TX               Neighborhood
# 164651                    Wooten, Austin, TX               Neighborhood
# 165090                   Hancock, Austin, TX               Neighborhood
# 165224             East Congress, Austin, TX               Neighborhood
# 190810             Franklin Park, Austin, TX               Neighborhood
# 191498                 St. Johns, Austin, TX               Neighborhood
# 191607                 Allandale, Austin, TX               Neighborhood
# 191745            South Manchaca, Austin, TX               Neighborhood
# 192331              Windsor Road, Austin, TX               Neighborhood
# 192390               Sweet Briar, Austin, TX               Neighborhood
# 192478  Pecan Springs Springdale, Austin, TX               Neighborhood
# 192500          University Hills, Austin, TX               Neighborhood
# 192538         Upper Boggy Creek, Austin, TX               Neighborhood
# 192653                  Highland, Austin, TX               Neighborhood
# 193430                 West Gate, Austin, TX               Neighborhood
# 193499            Coronado Hills, Austin, TX               Neighborhood
# 193547                     Holly, Austin, TX               Neighborhood
# 193953             West Congress, Austin, TX               Neighborhood
# 194015                      RMMA, Austin, TX               Neighborhood
# 194080                 Southeast, Austin, TX               Neighborhood
# 194740                  Chestnut, Austin, TX               Neighborhood
# 195367          Johnston Terrace, Austin, TX               Neighborhood
# 212380               North Lamar, Austin, TX               Neighborhood
# 213986         East Cesar Chavez, Austin, TX               Neighborhood
# 267609            Heritage Hills, Austin, TX               Neighborhood
# 308598                        Austintown, OH                       City
# 308822                            Austin, MN                       City
# 311778                            Austin, AR                       City
# 315971                       Austinville, VA                       City
# 317911                        Austinburg, OH                       City
# 318995                            Austin, TX                       City
# 342257                       Port Austin, MI                       City
# 459950                            Austin, IN                       City
# 485254                            Austin, PA                       City
# 487313                            Austin, KY                       City
# 687072                     78704, Austin, TX                   Zip Code
# 687078                     78745, Austin, TX                   Zip Code
# 687474                     78753, Austin, TX                   Zip Code
# 687628                     78748, Austin, TX                   Zip Code
# 688740                     78749, Austin, TX                   Zip Code
# 689472                     78731, Austin, TX                   Zip Code
# 689589                 44515, Austintown, OH                   Zip Code
# 689865                     78717, Austin, TX                   Zip Code
# 690105                     78703, Austin, TX                   Zip Code
# 690144                     78750, Austin, TX                   Zip Code
# 690204                     78746, Austin, TX                   Zip Code
# 690722                     78757, Austin, TX                   Zip Code
# 691129                     78702, Austin, TX                   Zip Code
# 691585                     78751, Austin, TX                   Zip Code
# 692255                     78735, Austin, TX                   Zip Code
# 693148                     78732, Austin, TX                   Zip Code
# 693153                     78747, Austin, TX                   Zip Code
# 693302                     78726, Austin, TX                   Zip Code
# 694883                     78730, Austin, TX                   Zip Code
# 695501                     72007, Austin, AR                   Zip Code
# 695534                     78733, Austin, TX                   Zip Code
# 761311                48467, Port Austin, MI                   Zip Code
#
#        area_cat_code
# 4018             M31
# 13351           M893
# 42197         CO1749
# 121430          N111
# 121685          N363
# 123005         N1683
# 126939         N2706
# 127010         N2736
# 135535        N10157
# 137280        N11707
# 138448        N11844
# 138554        N11852
# 142501        N11894
# 142561        N11895
# 142762        N11899
# 142808        N11900
# 142963        N11903
# 142973        N11904
# 143076        N11908
# 143186        N11914
# 143227        N11915
# 143231        N11917
# 143233        N11919
# 143239        N11920
# 143246        N11922
# 143260        N11924
# 143307        N11925
# 143331        N11926
# 143390        N11932
# 143475        N11940
# 145450        N11963
# 153158        N11973
# 153196        N11974
# 154126        N11977
# 154441        N11983
# 154523        N11985
# 154583        N11987
# 155726        N11993
# 155832        N11994
# 155834        N11995
# 156921        N12000
# 159119        N12056
# 160104        N12154
# 162437        N12335
# 164651        N12336
# 165090        N12337
# 165224        N12338
# 190810        N12431
# 191498        N12995
# 191607        N12449
# 191745        N12454
# 192331        N12472
# 192390        N12475
# 192478        N12478
# 192500        N12996
# 192538        N12480
# 192653        N12489
# 193430        N12534
# 193499        N12540
# 193547        N12542
# 193953        N12588
# 194015        N12598
# 194080        N12612
# 194740        N12708
# 195367        N12838
# 212380        N15546
# 213986        N15558
# 267609        N15654
# 308598         C1338
# 308822         C1562
# 311778         C4519
# 315971         C8713
# 317911        C10650
# 318995        C11734
# 342257        C14430
# 459950        C15902
# 485254        C22253
# 487313        C23630
# 687072        Z78704
# 687078        Z78745
# 687474        Z78753
# 687628        Z78748
# 688740        Z78749
# 689472        Z78731
# 689589        Z44515
# 689865        Z78717
# 690105        Z78703
# 690144        Z78750
# 690204        Z78746
# 690722        Z78757
# 691129        Z78702
# 691585        Z78751
# 692255        Z78735
# 693148        Z78732
# 693153        Z78747
# 693302        Z78726
# 694883        Z78730
# 695501        Z72007
# 695534        Z78733
# 761311        Z48467

# %% [markdown]
# ## Search the documentation for Meyerland

# %%
result_df = search_documentation(df, "meyerland")
result_df
# Out:
#                                area     area_type area_cat_code
# 137888  Meyerland Area, Houston, TX  Neighborhood        N11814
